# %%
import pandas as pd

# Read the first CSV file
df1 = pd.read_csv("C:\\Users\\adity\\OneDrive\\Desktop\\credit_risk.csv\\credit_risk.csv")

# Read the second CSV file
df2 = pd.read_csv("C:\\Users\\adity\\OneDrive\\Desktop\\credit_risk.csv\\new_credit_risk_dataset.csv")

# Concatenate the files along the rows
concatenated_df = pd.concat([df1, df2], ignore_index=True)

# Save the concatenated DataFrame to a new CSV file
concatenated_df.to_csv('merged_file.csv', index=False)

print("CSV files have been merged successfully!")
# Out:
# CSV files have been merged successfully!

# %%
concatenated_df
# Out:
#        Age  Income      Home  Emp_length     Intent  Amount   Rate  Status  \
# 0       22   59000      RENT       123.0   PERSONAL   35000  16.02       1
# 1       21    9600       OWN         5.0  EDUCATION    1000  11.14       0
# 2       25    9600  MORTGAGE         1.0    MEDICAL    5500  12.87       1
# 3       23   65500      RENT         4.0    MEDICAL   35000  15.23       1
# 4       24   54400      RENT         8.0    MEDICAL   35000  14.27       1
# ...    ...     ...       ...         ...        ...     ...    ...     ...
# 43076   28   58000  MORTGAGE        11.0    VENTURE  684487  19.41       0
# 43077   25   51780      RENT         8.0    MEDICAL  400692  17.27       1
# 43078   24  193000  MORTGAGE         8.0  EDUCATION  462822   6.66       0
# 43079   22   75600  MORTGAGE         3.0  EDUCATION  807270  18.85       0
# 43080   33   87120  MORTGAGE        10.0   PERSONAL  413851   6.74       0
#
#        Percent_income Default  Cred_length
# ...

# %%
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
type(concatenated_df)
# Out:
# pandas.core.frame.DataFrame

# %%
concatenated_df.shape
# Out:
# (43081, 11)

# %%
concatenated_df.describe()
# Out:
#                 Age        Income    Emp_length         Amount          Rate  \
# count  43081.000000  4.308100e+04  41910.000000   43081.000000  39965.000000
# mean      27.917156  6.641880e+04      4.975233  135456.994406     11.416317
# std        6.735691  5.959319e+04      4.579730  260764.142513      3.616038
# min       18.000000  4.000000e+03      0.000000     500.000000      5.000000
# 25%       23.000000  3.850000e+04      2.000000    6000.000000      8.000000
# 50%       26.000000  5.500000e+04      4.000000   10150.000000     11.300000
# 75%       30.000000  8.000000e+04      7.000000   30000.000000     13.980000
# max      144.000000  6.000000e+06    123.000000  999967.000000     23.220000
#
#              Status  Percent_income  Cred_length
# count  43081.000000    43081.000000  43081.00000
# mean       0.221652        0.171266      5.91191
# std        0.415363        0.107618      4.25457
# min        0.000000        0.000000      1.00000
# ...

# %%
concatenated_df.isnull().sum()
# Out:
# Age                  0
# Income               0
# Home                 0
# Emp_length        1171
# Intent               0
# Amount               0
# Rate              3116
# Status               0
# Percent_income       0
# Default              0
# Cred_length          0
# dtype: int64

# %%
concatenated_df = concatenated_df.dropna()

# %%
concatenated_df.isnull().sum()
# Out:
# Age               0
# Income            0
# Home              0
# Emp_length        0
# Intent            0
# Amount            0
# Rate              0
# Status            0
# Percent_income    0
# Default           0
# Cred_length       0
# dtype: int64

# %%
concatenated_df.replace({"Default":{'N':0,'Y':1}},inplace=True)
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_4036\1933848398.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   concatenated_df.replace({"Default":{'N':0,'Y':1}},inplace=True)

# %%
concatenated_df.head()
# Out:
#    Age  Income      Home  Emp_length     Intent  Amount   Rate  Status  \
# 0   22   59000      RENT       123.0   PERSONAL   35000  16.02       1
# 1   21    9600       OWN         5.0  EDUCATION    1000  11.14       0
# 2   25    9600  MORTGAGE         1.0    MEDICAL    5500  12.87       1
# 3   23   65500      RENT         4.0    MEDICAL   35000  15.23       1
# 4   24   54400      RENT         8.0    MEDICAL   35000  14.27       1
#
#    Percent_income  Default  Cred_length
# 0            0.59        1            3
# 1            0.10        0            2
# 2            0.57        0            3
# 3            0.53        0            2
# 4            0.55        1            4

# %%
concatenated_df['Home'].value_counts()
# Out:
# Home
# RENT        19599
# MORTGAGE    16020
# OWN          3114
# OTHER         129
# Name: count, dtype: int64

# %%
concatenated_df = concatenated_df[concatenated_df['Home'] != 'OTHER']
concatenated_df.to_csv('filtered_file.csv', index=False)

# %%
concatenated_df['Home'] = concatenated_df['Home'].replace({'RENT': 'OWN', 'OWN': 'RENT'})
concatenated_df.to_csv('modified_file.csv', index=False)

# %%
concatenated_df['Home'].value_counts()
# Out:
# Home
# OWN         19599
# MORTGAGE    16020
# RENT         3114
# Name: count, dtype: int64

# %%
concatenated_df.replace({"Home":{'RENT':0,'OWN':1,'MORTGAGE':2}},inplace=True)

# %%
concatenated_df.head()
# Out:
#    Age  Income  Home  Emp_length     Intent  Amount   Rate  Status  \
# 0   22   59000     1       123.0   PERSONAL   35000  16.02       1
# 1   21    9600     0         5.0  EDUCATION    1000  11.14       0
# 2   25    9600     2         1.0    MEDICAL    5500  12.87       1
# 3   23   65500     1         4.0    MEDICAL   35000  15.23       1
# 4   24   54400     1         8.0    MEDICAL   35000  14.27       1
#
#    Percent_income  Default  Cred_length
# 0            0.59        1            3
# 1            0.10        0            2
# 2            0.57        0            3
# 3            0.53        0            2
# 4            0.55        1            4

# %%
concatenated_df['Intent'].value_counts()
# Out:
# Intent
# EDUCATION            7731
# MEDICAL              7241
# PERSONAL             6692
# VENTURE              6682
# DEBTCONSOLIDATION    6072
# HOMEIMPROVEMENT      4315
# Name: count, dtype: int64

# %%
concatenated_df.replace({"Intent":{'EDUCATION':0,'MEDICAL':1,'PERSONAL':2,'DEBTCONSOLIDATION':3,'VENTURE':4,'HOMEIMPROVEMENT':5}},inplace=True)

# %%
concatenated_df.head()
# Out:
#    Age  Income  Home  Emp_length  Intent  Amount   Rate  Status  \
# 0   22   59000     1       123.0       2   35000  16.02       1
# 1   21    9600     0         5.0       0    1000  11.14       0
# 2   25    9600     2         1.0       1    5500  12.87       1
# 3   23   65500     1         4.0       1   35000  15.23       1
# 4   24   54400     1         8.0       1   35000  14.27       1
#
#    Percent_income  Default  Cred_length
# 0            0.59        1            3
# 1            0.10        0            2
# 2            0.57        0            3
# 3            0.53        0            2
# 4            0.55        1            4

# %%
sns.countplot(x='Home',hue='Status',data=concatenated_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 sns.countplot(x='Home',hue='Status',data=concatenated_df)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
#     764     ax.set_ylim(-.5, len(self.plot_data) - .5, auto=None)
# ...

# %%
X = concatenated_df.drop(columns=['Status'],axis=1)
Y = concatenated_df['Status']
print(X)
print(Y)
# Out:
#        Age  Income  Home  Emp_length  Intent  Amount   Rate  Percent_income  \
# 0       22   59000     1       123.0       2   35000  16.02            0.59
# 1       21    9600     0         5.0       0    1000  11.14            0.10
# 2       25    9600     2         1.0       1    5500  12.87            0.57
# 3       23   65500     1         4.0       1   35000  15.23            0.53
# 4       24   54400     1         8.0       1   35000  14.27            0.55
# ...    ...     ...   ...         ...     ...     ...    ...             ...
# 43076   28   58000     2        11.0       4  684487  19.41            0.17
# 43077   25   51780     1         8.0       1  400692  17.27            0.23
# 43078   24  193000     2         8.0       0  462822   6.66            0.05
# 43079   22   75600     2         3.0       0  807270  18.85            0.13
# 43080   33   87120     2        10.0       2  413851   6.74            0.03
#
#        Default  Cred_length
# ...

# %%
X_train, X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,stratify=Y,random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
